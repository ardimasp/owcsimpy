# %%
# %matplotlib notebook

# %%
# from . import TypicalSimpleOfficeEnv_py as TypicalOfficeEnv
from owcsimpy.geoobjects.models.typicalsimpleofficeenv_py import TypicalSimpleOfficeEnv_py as TypicalOfficeEnv
from owcsimpy.cir.freqdomaincir import FreqDomainCIR
from owcsimpy.cir.timedomaincir import TimeDomainCIR
from owcsimpy.cir.spheremodelcir import SphereModelCIR
from scipy.constants import speed_of_light
from owcsimpy.cir.cirutils import calcCIRFreqDom_fromMtx
import numpy as np

import matplotlib.pyplot as plt

import scipy.io

roomLength,roomWidth,roomHeight=4,3,3

# %%
# Case 1
position, furnitureConfig, humanLoc, humanDirection, activity = \
    'standing','cornerYFacingWall',[2.5,1.5],np.deg2rad(-45),'calling'

# position, furnitureConfig, humanLoc, humanDirection, activity = \
#     'sitting','cornerYFacingWall',[3.5,2.5],np.deg2rad(-135),'usbdongle'


# position, furnitureConfig, humanLoc, humanDirection, activity = \
#     'standing','cornerYFacingWall',[3.5,2.5],np.deg2rad(-135),'calling'


office1 = TypicalOfficeEnv(
    roomDim=[roomLength,roomWidth,roomHeight],
    humanLoc=humanLoc,humanDirection=humanDirection,
    mode='rx',
    activity=activity,
    position=position,
    furnitureConfig=furnitureConfig
)


fig,ax = office1.draw();
print('is valid:', office1.isValid)

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)
ht1_los_td, ht1_diff_td = tdcir1.calc(office1.led,office1.human.pd,office1.blockingObj,office1.room,
                                   numReflections=3,partitionDist=speed_of_light*0.5e-9)

scipy.io.savemat('case1_dl.mat', dict(t=tdcir1.t, los=ht1_los_td, nlos=ht1_diff_td))

fig, [ax1,ax2] = plt.subplots(2,1,figsize=(6,4))
ax1.plot(tdcir1.t,ht1_los_td+ht1_diff_td)
ax2.plot(tdcir1.t,ht1_diff_td)

office1 = TypicalOfficeEnv(
    roomDim=[roomLength,roomWidth,roomHeight],
    humanLoc=humanLoc,humanDirection=humanDirection,
    mode='tx',
    activity=activity,
    position=position,
    furnitureConfig=furnitureConfig
)

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)
ht1_los_td, ht1_diff_td = tdcir1.calc(office1.human.led,office1.pd,office1.blockingObj,office1.room,
                                   numReflections=3,partitionDist=speed_of_light*0.5e-9)

scipy.io.savemat('case1_ul.mat', dict(t=tdcir1.t, los=ht1_los_td, nlos=ht1_diff_td))


fig, [ax1,ax2] = plt.subplots(2,1,figsize=(6,4))
ax1.plot(tdcir1.t,ht1_los_td+ht1_diff_td)
ax2.plot(tdcir1.t,ht1_diff_td)
# Out:
# <img src="data:image/png;base64,..." width="500">
# is valid: True
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %%
# Case 1
# position, furnitureConfig, humanLoc, humanDirection, activity = \
#     'standing','cornerYFacingWall',[2.5,1.5],np.deg2rad(-45),'calling'

position, furnitureConfig, humanLoc, humanDirection, activity = \
    'sitting','cornerYFacingWall',[3.5,2.5],np.deg2rad(-135),'usbdongle'


# position, furnitureConfig, humanLoc, humanDirection, activity = \
#     'standing','cornerYFacingWall',[3.5,2.5],np.deg2rad(-135),'calling'


office1 = TypicalOfficeEnv(
    roomDim=[roomLength,roomWidth,roomHeight],
    humanLoc=humanLoc,humanDirection=humanDirection,
    mode='rx',
    activity=activity,
    position=position,
    furnitureConfig=furnitureConfig
)


fig,ax = office1.draw();
print('is valid:', office1.isValid)

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)
ht1_los_td, ht1_diff_td = tdcir1.calc(office1.led,office1.human.pd,office1.blockingObj,office1.room,
                                   numReflections=3,partitionDist=speed_of_light*0.5e-9)

scipy.io.savemat('case2_dl.mat', dict(t=tdcir1.t, los=ht1_los_td, nlos=ht1_diff_td))

fig, [ax1,ax2] = plt.subplots(2,1,figsize=(6,4))
ax1.plot(tdcir1.t,ht1_los_td+ht1_diff_td)
ax2.plot(tdcir1.t,ht1_diff_td)

office1 = TypicalOfficeEnv(
    roomDim=[roomLength,roomWidth,roomHeight],
    humanLoc=humanLoc,humanDirection=humanDirection,
    mode='tx',
    activity=activity,
    position=position,
    furnitureConfig=furnitureConfig
)

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)
ht1_los_td, ht1_diff_td = tdcir1.calc(office1.human.led,office1.pd,office1.blockingObj,office1.room,
                                   numReflections=3,partitionDist=speed_of_light*0.5e-9)

scipy.io.savemat('case2_ul.mat', dict(t=tdcir1.t, los=ht1_los_td, nlos=ht1_diff_td))


fig, [ax1,ax2] = plt.subplots(2,1,figsize=(6,4))
ax1.plot(tdcir1.t,ht1_los_td+ht1_diff_td)
ax2.plot(tdcir1.t,ht1_diff_td)
# Out:
# <img src="data:image/png;base64,..." width="500">
# is valid: True
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %%
# Case 1
# position, furnitureConfig, humanLoc, humanDirection, activity = \
#     'standing','cornerYFacingWall',[2.5,1.5],np.deg2rad(-45),'calling'

# position, furnitureConfig, humanLoc, humanDirection, activity = \
#     'sitting','cornerYFacingWall',[3.5,2.5],np.deg2rad(-135),'usbdongle'


position, furnitureConfig, humanLoc, humanDirection, activity = \
    'standing','cornerYFacingWall',[3.5,2.5],np.deg2rad(-135),'calling'


office1 = TypicalOfficeEnv(
    roomDim=[roomLength,roomWidth,roomHeight],
    humanLoc=humanLoc,humanDirection=humanDirection,
    mode='rx',
    activity=activity,
    position=position,
    furnitureConfig=furnitureConfig
)


fig,ax = office1.draw();
print('is valid:', office1.isValid)

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)
ht1_los_td, ht1_diff_td = tdcir1.calc(office1.led,office1.human.pd,office1.blockingObj,office1.room,
                                   numReflections=3,partitionDist=speed_of_light*0.5e-9)

scipy.io.savemat('case3_dl.mat', dict(t=tdcir1.t, los=ht1_los_td, nlos=ht1_diff_td))

fig, [ax1,ax2] = plt.subplots(2,1,figsize=(6,4))
ax1.plot(tdcir1.t,ht1_los_td+ht1_diff_td)
ax2.plot(tdcir1.t,ht1_diff_td)

office1 = TypicalOfficeEnv(
    roomDim=[roomLength,roomWidth,roomHeight],
    humanLoc=humanLoc,humanDirection=humanDirection,
    mode='tx',
    activity=activity,
    position=position,
    furnitureConfig=furnitureConfig
)

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)
ht1_los_td, ht1_diff_td = tdcir1.calc(office1.human.led,office1.pd,office1.blockingObj,office1.room,
                                   numReflections=3,partitionDist=speed_of_light*0.5e-9)

scipy.io.savemat('case3_ul.mat', dict(t=tdcir1.t, los=ht1_los_td, nlos=ht1_diff_td))


fig, [ax1,ax2] = plt.subplots(2,1,figsize=(6,4))
ax1.plot(tdcir1.t,ht1_los_td+ht1_diff_td)
ax2.plot(tdcir1.t,ht1_diff_td)
# Out:
# <img src="data:image/png;base64,..." width="500">
# is valid: True
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %%
# %%time 

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)
ht1_los_td, ht1_diff_td = tdcir1.calc(office1.led,office1.human.pd,office1.blockingObj,office1.room,
                                   numReflections=1,partitionDist=speed_of_light*0.5e-9)

np.sum(ht1_los_td)
# Out:
# CPU times: user 397 ms, sys: 0 ns, total: 397 ms
# Wall time: 396 ms
# 3.0895275953835192e-06

# %%
# %%time 

tdcir1 = TimeDomainCIR(timeSampling=0.5e-9)

ht1_los_td, ht1_diff_td = tdcir1.calc(office1.human.led,office1.pd,office1.blockingObj,office1.room,
                                   numReflections=3,partitionDist=speed_of_light*0.5e-9)
# Out:
# 1.4039048823976258e-05

# %%
office1.mode
# Out:
# 'rx'
